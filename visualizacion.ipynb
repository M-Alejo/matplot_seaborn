# %% [markdown]
# # Visualización de datos con Matplotlib y Seaborn, siguiendo un curso

# %% [markdown]
# ## Matplotlib
# * librería escrita por John D. Hunter, creada en 2003
# * Está basada en NumPy, escrita en python, emula comando de MatLab
# * Es simple para utilizar
# * Es rápida y personalizable
#
# Resumen de manejo de MatplotLib puede encontrarse en [Este sitio](https://matplotlib.org/cheatsheets/), abajo un ejemplo tomado de allí.
# ![Ejemplo](./resumen_matplotlib.webp)

# %%
# importar librerias
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Pyplot básico

# %%
# crear variables x e y
x = np.linspace(0,5,11)
y = x**2

# %%
# crear grafica
plt.plot(x,y)
plt.show()

# %%
# crear modificar color de graficas y marcadores
plt.plot(x, y, 'rx')
plt.show()

# %%
# crear modificar color de graficas y marcadores y agregar linea continua
plt.plot(x, y, 'rs-') # r: color rojo; s:forma cuadrados; -:linea continua
plt.show()

# %%
# crear modificar color de graficas y marcadores y agregar linea punteada
plt.plot(x, y, 'yD:') # y: color amarillo; D:forma diamante; ::linea punteada
plt.show()

# %%
# crear histograma
plt.hist(x)
plt.show()

# %%
# crear gráfica de pie  torta
plt.pie(x)
plt.show()

# %%
# crear gráfica de scatter, para relacionar dos variables
plt.scatter(x, y)
plt.show()

# %%
# crear gráfica boxplot de una variable
plt.boxplot(x)
plt.show()

# %% [markdown]
# ### Manejo de Subplot

# %%
# crear subplot parametros (nfilas, ncolumnas, indice actual)
plt.subplot(1, 2, 1) # una fila dos columnas cajita uno
plt.plot(x,y)

plt.subplot(1, 2, 2) # una fila dos columnas cajita dos
plt.hist(y)

plt.show()

# %%
# crear subplot parametros (nfilas, ncolumnas, indice actual)
plt.subplot(1, 2, 1) # una fila dos columnas cajita uno
plt.plot(x,y, 'r--') # primera grafica en la caja uno
plt.plot(y,x, 'b:') # segunda grafica en la caja uno

plt.subplot(1, 2, 2) # una fila dos columnas cajita dos
plt.pie(y)

plt.show()

# %%
# crear subplot parametros (nfilas, ncolumnas, indice actual)
plt.subplot(2, 1, 1) # una fila dos columnas cajita uno
plt.plot(x,y, 'r--') # primera grafica en la caja uno
plt.plot(y,x, 'b:') # segunda grafica en la caja uno

plt.subplot(2, 1, 2) # una fila dos columnas cajita dos
plt.pie(y)

plt.show()

# %% [markdown]
# ### Método orientado a objeto en Matplotlib
# Aunque tiene un poco más de código se puede personalizar más.
# Pasos:
# * Definir lienzo con: nombre_lienzo =  plt.figure()
# * Agregar axes o cuadro donde va la primera gráfica con: nombre_axes = fig.add_axes([posx, posy, sizex, sizey])
# * Agregar gráfica en axes o cuadro creado con nombre_axes.plot()
# * Agregar a cada axes la configuración deseada
# * mostrar el lienzo con nombre_lienzo.show()

# %% [markdown]
# ![Método orientado a objetos](./metodo_oop.png) ![Ejemplo](ejemplo_oop.png) ![Estructura general de una figura](./estructura_oop.png) ![Personalizar](./personalizable_oop2.png)
#
# Figuras tomadas de [Matplotlib](https://matplotlib.org/stable/gallery/showcase/anatomy.html)

# %%
# usando metodo orientago a objetos
fig = plt.figure() # lienzo sobre el que se hacen las figuras
axes = fig.add_axes([0.1, 0.1, 0.5, 0.9]) # [posx, posy, xsize, ysize] los dos primeros indican la posicion en el lienzo, los otros dos el tamano
axes.plot(x, y, 'b')
fig.show()

# %%
# usando metodo orientago a objetos

# definir lienzo
fig = plt.figure() # lienzo sobre el que se hacen las figuras

# definir axes
axes = fig.add_axes([0.1, 0.1, 0.8, 0.9]) # [posx, posy, xsize, ysize] los dos primeros indican la posicion en el lienzo, los otros dos el tamano
axes2 = fig.add_axes([0.1, 0.1, 0.4, 0.3]) # [posx, posy, xsize, ysize] los dos primeros indican la posicion en el lienzo, los otros dos el tamano

# agregar graficas en cada axes
axes.plot(x, y, 'b')
axes2.plot(y, x, 'r--')

#mostrar el lienzo
fig.show()

# %%
# usando metodo orientago a objetos

# definir lienzo
fig = plt.figure() # lienzo sobre el que se hacen las figuras

# definir axes
axes = fig.add_axes([0.1, 0.1, 0.8, 0.9]) # [posx, posy, xsize, ysize] los dos primeros indican la posicion en el lienzo, los otros dos el tamano
axes2 = fig.add_axes([0.2, 0.55, 0.4, 0.3]) # [posx, posy, xsize, ysize] los dos primeros indican la posicion en el lienzo, los otros dos el tamano

# agregar graficas en cada axes
axes.plot(x, y, 'b')
axes2.plot(y, x, 'r--')

# personalizar axes
axes2.set_facecolor('gray')

#mostrar el lienzo
fig.show()

# %% [markdown]
# ### Subplots con método orientado a objetos

# %%
# subplots sirve para agregar varios axes en una figura nrows, ncols define cuantas, si se pasa sin argumentos crea un solo axes
fig, axes = plt.subplots()
axes.plot(x,y, 'b')

#se muestra el lienzo completo
fig.show()

# %%
# subplots sirve para agregar varios axes en una figura nrows, ncols define cuantas axes es un array
# se crea el lienzo fig, con los axes como array
fig, axes = plt.subplots(nrows=1, ncols=2)

#grafico en el primer axes, el primer axes es 0
axes[0].plot(x,y, 'b')

#grafico en el segundo axes
axes[1].plot(y,x, 'r:')

#se muestra el lienzo completo
fig.show()

# %%
# subplots sirve para agregar varios axes en una figura nrows, ncols define cuantas axes es un array

# se crea el lienzo fig, los axes se asignan con una tupla
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

#grafico en ax1
ax1.plot(x,y, 'b')

#grafico en ax2
ax2.plot(y,x, 'r:')

#se muestra el lienzo completo
fig.show()

# %%
# subplots sirve para agregar varios axes en una figura nrows, ncols define cuantas axes es un array

# se crea el lienzo fig, con ocho axes organizados en dos filas y cuatro columnas
fig, axes = plt.subplots(nrows=2, ncols=4)

#grafico en axes[0,0]: [nfila, ncolummna], el axes de la primera fila y la primera columna
axes[0,0].plot(x,y, 'b')

#grafico en axes[0,1] : [nfila, ncolumna], el axes de la primera fila y la segunda columna
axes[0,1].plot(y,x, 'r:')

#se muestra el lienzo completo
fig.show()

# %%
# subplots sirve para agregar varios axes en una figura nrows, ncols define cuantas axes es un array

# se crea el lienzo fig, con ocho axes organizados en dos filas y cuatro columnas, con nombre propios dados por tupla
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(nrows=2, ncols=4) # despues de fig van los nombres de los axes ((axes de primera fila),(axes de segundafila))

# grafico en ax1, el axes de la primera fila y la primera columna
ax1.plot(x,y, 'b')

# grafico en ax2, el axes de la primera fila y la segunda columna
ax2.plot(x**3,y, 'b--')

# grafico en ax3, el axes de la primera fila y la tercera columna
ax3.plot(x,y**3, 'y:')

# grafico en ax4, el axes de la primera fila y la cuarta columna
ax4.plot(x,y**2, 'bs-')

# grafico en ax8, el axes de la segunda fila y ultima columna
ax8.plot(y,x, 'r:')

# se ajusta la distancia entre figuras
fig.tight_layout()

#se muestra el lienzo completo
fig.show()

# %% [markdown]
# ### Leyendas, etiquetas, títulos y tamaño

# %%
# se crea lienzo y axes, en la creacion de la figura se define el tamano del lienzo con figsize=(xdim, ydim)
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(5, 5))

# se grafica en el axes[0]
axes[0].plot(x, y, label='línea x') # agrega grafica con nombre de linea en label='nombre de linea'
axes[0].set_title('Relación X vs Y') # se agrega titulo a grafica
axes[0].set_xlabel('x') # se agrega titulo de eje x
axes[0].set_ylabel('y') # se agrega titulo de eje y
axes[0].legend() # para mostrar nombre de lineas o leyenda de la grafica

# grafica en el axes[1]
axes[1].plot(y, x, label='línea y')
axes[1].set_title('Relación Y vs X') # se agrega titulo a grafica
axes[1].set_xlabel('y') # se agrega titulo de eje x
axes[1].set_ylabel('x') # se agrega titulo de eje y
axes[1].legend() # para mostrar nombre de lineas o leyenda de la grafica

# se muestra la figura
fig.show()

# %% [markdown]
# ### Colores y estilos

# %%
# para saber que estilos hay disponibles
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# definirle a matplot que estilo usar
plt.style.use('seaborn-v0_8')

# %%
# se crea lienzo y axes, en la creacion de la figura se define el tamano del lienzo con figsize=(xdim, ydim)
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(5, 5))

# se grafica en el axes[0]
axes[0].plot(x, y, label='línea x') # agrega grafica con nombre de linea en label='nombre de linea'
axes[0].set_title('Relación X vs Y') # se agrega titulo a grafica
axes[0].set_xlabel('x') # se agrega titulo de eje x
axes[0].set_ylabel('y') # se agrega titulo de eje y
axes[0].legend() # para mostrar nombre de lineas o leyenda de la grafica

# grafica en el axes[1]
axes[1].plot(y, x, label='línea y')
axes[1].set_title('Relación Y vs X') # se agrega titulo a grafica
axes[1].set_xlabel('y') # se agrega titulo de eje x
axes[1].set_ylabel('x') # se agrega titulo de eje y
axes[1].legend() # para mostrar nombre de lineas o leyenda de la grafica

# se muestra la figura
fig.show()

# %% [markdown]
# #### Manejar estilos de línea con la notación MATLAB
# La notación MATLAB es la que va entre comillas sencillas por ejemplo 'yo-' que significa color amarillo, marcador de punto y linea que une marcadores

# %%
# crear figura
fig, ax = plt.subplots(figsize=(8,8))

ax.plot(x, x+1, 'yo-') # grafica color amarilla con marcador de punto y linea
ax.plot(x, x+2, 'bD-') # grafica color azul con marcador de diamante y linea
ax.plot(x, x+3, 'r:') # grafica colo rojo linea punteada sin marcador
ax.plot(x, x+4, 'o') # grafica con marcador de punto sin linea

# se muestra la figura
fig.show()

# %% [markdown]
# #### Manejar estilos con propiedades de MatplotLib
# Con Matplotlib se accede a la propiedad por el nombre

# %%
# crear figura
fig, ax = plt.subplots(figsize=(8,8))

# grafica 1
ax.plot(x, x+1, # datos que grafica
        color='green', # color de linea
        alpha=0.5, # transparencia de linea
        linewidth=1, # grosor de linea
        linestyle='dashed', # estio de linea
        marker='o', # marcador redondo
        markersize=10, # tamano de marcador
        markerfacecolor='blue' # color de marcador
        ) 

# grafica 2
ax.plot(x, x+2, # datos que grafica
        color='blue', # color de linea
        alpha=0.7, # transparencia de linea
        linewidth=2, # grosor de linea
        linestyle='-', # estio de linea continua
        marker='X' # marcador de x
        )

# grafica 3
ax.plot(x, x+3, # datos que grafica
        color='black', # color de linea
        alpha=1, # transparencia de linea
        linewidth=3, # grosor de linea
        linestyle=':', # estio de linea punteada
        marker='s' # marcador de cuadrado
        ) 

# grafica 4
ax.plot(x, x+4, # datos que grafica
        color='green', # color de linea
        alpha=0.5, # transparencia de linea
        linewidth=4, # grosor de linea
        linestyle='--', # estio de linea
        marker='D' # marcador de diamante
        ) 

# se muestra la figura
fig.show()

# %% [markdown]
# ### Bar plot con pyplot, para variables categoricas

# %%
# definir variables categoricas
paises = ['INDIA', 'JAPON', 'MEXICO', 'COLOMBIA', 'ALEMANIA']
poblacion = [1000, 800, 900, 1200, 300]

# %%
# grafica de barras con pyplot
plt.bar(paises, poblacion)
plt.show()

# %%
# grafica de barras modificada con pyplot

plt.bar(paises, # categorias
        poblacion, # valores
        width=0.5, #ancho de barras
        color=['blue', 'green'] # poniendo dos colores python los alterna
        )

# cambiar nombres de eje x
plt.xticks(
    np.arange(5), # se pone la cantidad de categorias que tenga, en este caso son cinco paises
    ('India', 'Japón', 'México', 'Colombia', 'Alemania'), #nombres que quiero poner, deben estar en el mismo orden de las categorias iniciales
    rotation=45 # rotar los nombres de categorias en grados
)

plt.show()

# %%
# grafica de barras horizontal
plt.barh(paises, poblacion)
plt.show()

# %%
# tambien se pueden cambiar colores igual que con las barras verticales

plt.barh(paises, # categorias
        poblacion, # valores
        color=['blue', 'green'] # poniendo dos colores python los alterna
        )

# cambiar nombres de eje y
plt.yticks(
    np.arange(5), # se pone la cantidad de categorias que tenga, en este caso son cinco paises
    ('India', 'Japón', 'México', 'Colombia', 'Alemania') #nombres que quiero poner, deben estar en el mismo orden de las categorias iniciales
)

plt.show()

# %% [markdown]
# ### Otros gráficos

# %%
# se crea un conjunto de 100 datos aleatorio con valores enteros entre 1 y 50
datos = np.random.randint(1, 50, 100)
print(datos)
# Out:
# [ 8  6 47 22 15 48  4 14 44 32 14 47 38 15 47 14 26 13 26  1 46 26 48 38
#  20 28 29 25 23 48 12 16 36  9  2  7 41 29 25 25  8 10 40 48  9 39 12 45
#  24 35  5 26 22  6 20 10 28 34 19 35 31 31 40 49 43 16 40  5 11  4 16 40
#  43 28 49 46 16 45 18 24 16  4 14 41 10 28  3 40 35 44 44 16 45 12 33 20
#   5 18 27 17]

# %% [markdown]
# #### Histograma con pyplot

# %%
# grafica de histograma, util para ver distribucion de frecuencias
plt.hist(datos, #datos usados para graficar
         bins='sturges', # numero de barras, por defecto viene en 10, se puede definir con un metodo: 'auto', 'fd', 'doane', 'scott', 'stone', 'rice', 'sturges', or 'sqrt'.
         width=3 #ancho de las barras
         )

plt.show()

# %% [markdown]
# #### Boxplot con pyplot

# %%
# hacer grafica de boxplot con pyplot

plt.boxplot(datos, # datos con los que se hace el boxplot
            vert=False, # para ponerlo horizontal, s esta en True el boxplot sale vertical
            patch_artist=True, # para rellenar la caja, si esta en False no viene rellena la caja
            notch=True, # para angostar en el percentil 50
            showfliers=True # para ocultar mostrar valores atipicos, si esta en false los oculta
            )
# mostrar la figura
plt.show()

# %% [markdown]
# #### Scatter plotcon pyplot

# %%
# crear datos aleatorios
n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30*  np.random.rand(n)) ** 2
colors = np.random.rand(n)

# %%
# grafica de scatter con pyplot
plt.scatter(x, y)
plt.show()

# %%
# grafica de scatter con pyplot, agregando otras caracteristicas
plt.scatter(x, # datos eje x
            y, # datos eje y
            s=area, # tamano de puntos, se peude asociar a otra variable
            c = colors, # colores de puntos
            marker='X', # tipo de marcador
            alpha=0.5 # transparencia, se mostraria mas oscuro en donde haya mas sobreposicion de datos
            )

plt.show()

# %% [markdown]
# ## Seaborn
# * Escrita por Michael Waskom
# * Está construida sobre Matplotlib por loque hereda todas las bondades
# * Integrada para estructuras de Pandas por lo que funciona mejor con DataFrames
# * Es muy rápida
# * Requiere poco código para hacer buenas gráficas
# * Se puede personalizar gráficas y visualizaciones
#
# Estructura basica en seaborn:
#
# ```python
# sns."Tipo de gráfica"(
#     data = "Dataset",
#     x="datos de eje x",
#     y="datos de eje y",
#     hue="variable de agrupamiento"
#     )
# ```
#
# ![Tipos de grafica con seaborn](tipo_grafica_seaborn.png)

# %%
# importar libreria de seaborn y matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set o configuración básica de las gráficas que se van a generar
# * Seaborn tiene cinco temas: *darkgrid*, *whitegrid*, *dark*, *white*, *ticks*. Más información [Aquí](https://seaborn.pydata.org/tutorial/aesthetics.html?highlight=sns+set)
# * Seaborn tiene seis paletas de colores: *pastel*, *muted*, *bright*, *deep*, *colorblind*, *dark*. Más información [Aquí](https://seaborn.pydata.org/tutorial/color_palettes.html?highlight=palette)

# %%
#tema darkgrid
sns.set(style='darkgrid')

#grafica
sns.barplot(x=['A', 'B', 'C'],
            y=[1, 3, 2])
plt.show()

# %%
#tema whitegrid
sns.set(style='whitegrid')

#grafica
sns.barplot(x=['A', 'B', 'C'],
            y=[1, 3, 2])
plt.show()

# %%
#tema white
sns.set(style='white')

#grafica
sns.barplot(x=['A', 'B', 'C'],
            y=[1, 3, 2])
plt.show()

# %%
#tema dark
sns.set(style='dark')

#grafica
sns.barplot(x=['A', 'B', 'C'],
            y=[1, 3, 2])
plt.show()

# %%
#tema ticks
sns.set(style='ticks')

#grafica
sns.barplot(x=['A', 'B', 'C'],
            y=[1, 3, 2])
plt.show()

# %%
# con set se puden cambiar tambien la paleta de colores, tamanp de letra
sns.set(style='darkgrid', # color de fondo
        palette='dark', # colores de barras
        font_scale=2 # tamano de fuente
        )

# grafica
sns.barplot(x=['A', 'B', 'C'],
            y=[1, 3, 2])
plt.show()

# %% [markdown]
# ### Parámetros más usados en Seaborn
# Algunos tipos de gráfico se muestran a continuación
#
# ![tipo_grafico_sns](./tipos_grafico_sns.png)
#
# Otros tipos de graficas y ejemplos [acá](https://cheatography.com//aggialavura/cheat-sheets/python-seaborn-imgs/pdf/)

# %%
# con set se puden cambiar tambien la paleta de colores, tamanp de letra
sns.set(style='darkgrid', # color de fondo
        palette='colorblind' # colores de barras
        )

# %%
# usar conjunto de datos precargado de seaborn, se usan los datos tips
propinas = sns.load_dataset('tips')

# %%
# mostrar los primeros registros
propinas.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### Primeros gráficos con *displot*

# %%
# grafico displot con una variable hace un histograma de frecuencias
sns.displot(
    data = propinas, # conjunto de datos, puede ser un DataFrame
    x = 'total_bill' # valores eje x, nombre de columna de conjunto de datos
)

# mostrar la grafica
plt.show()

# %%
# grafico displot con dos variables hace un cmap
sns.displot(
    data = propinas, # conjunto de datos, puede ser un DataFrame
    x = 'total_bill', # valores eje x, nombre de columna del conjunto de datos
    y= 'tip' # valores eje y, nombre de columna del conjunto de datos
)

# mostrar grafica
plt.show()

# %%
# grafico displot con dos variables hace un cmap
sns.displot(
    data = propinas, # conjunto de datos, puede ser un DataFrame
    x = 'total_bill', # valores eje x, nombre de columna del conjunto de datos
    y= 'tip', # valores eje y, nombre de columna del conjunto de datos
    hue='sex' # agrupacion por tipo de dato categorico, se pone nombre de columna del conjunto de datos
)

# mostrar grafica
plt.show()

# %%
# grafico displot son de distribucion
sns.displot(
    data = propinas, # conjunto de datos, puede ser un DataFrame
    x = 'total_bill', # valores eje x, nombre de columna del conjunto de datos
    hue='sex', # agrupacion por tipo de dato categorico, se pone nombre de columna del conjunto de datos
    kind='kde' # kind es tipo de grafico no todos tienen esta propiedad, kde significa densidad
)

# mostrar grafica
plt.show()

# %%
# grafico displot son de distribucion
sns.displot(
    data = propinas, # conjunto de datos, puede ser un DataFrame
    x = 'total_bill', # valores eje x, nombre de columna del conjunto de datos
    hue='sex', # agrupacion por tipo de dato categorico, se pone nombre de columna del conjunto de datos
    kind='kde', # kind es tipo de grafico no todos tienen esta propiedad, kde significa densidad
    legend=True, # para que muestre la leyenda. Si se pone False la oculta
    palette='dark', # cambia el tipo de paleta de colores que se define en set, lo hace unicamente para esta grafica
    alpha=0.5 # cambia la transparencia de las graficas, valor cercano a cero mas transparente
)

# mostrar grafica
plt.show()

# %% [markdown]
# ### Gráfico de distribuciones con Seaborn

# %%
propinas.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### Histogramas
# Documentación de histplot en [este sitio](https://seaborn.pydata.org/generated/seaborn.histplot.html)
#
# * Parámetro *bins* tiene las siguientes opciones:
#     * si se ingresa un entero es el número de separaciones que hará, distribuye todos los datos en intervalos iguales para el entero dado
#     * *auto*: toma el valor máximo entre el estimador 'sturges' y 'fd'. Provee un buen desempeño para graficar
#     * *fd*:Freedman Diaconis Estimator, es un estimador robusto que toma en cuenta la variabilidad de los datos y su tamaño
#     * *doane*: Es una mejora de el estimador 'sturges' que trabaja mejor con datos que no siguen una distribución normal
#     * *scott*: Es el estimador menos robusto tiene en cuenta la variabilidad de los datos y el tamaño de los mismos
#     * *rice*: Este estimador no tiene en cuenta la variabilidad de los datos, únicamente tiene en cuenta el tamaño, normalmente sobre estima el número de bins que se requieren
#     * *sturges*: Método común usado también en R por defecto. Sólo tiene en cuenta el tamaño de los datos, es óptimo para datos que siguen una distibución normal o datos gaussianos
#     * *sqrt*: Raíz cuadrada del tamaño de los datos, es usado en Excel y otros programas por su velocidad de ejecución y simplicidad
#
# * Parámetro *stat* tiene las siguientes opciones:
#     * *count*: muestra el número de observaciones en cada bin
#     * *frequency*: muestra el número de observaciones dividido entre el ancho del bin
#     * *probability o proportion*: normaliza los datos de tal forma que la suma de altura total de todas las barras es igual a 1
#     * *percent*: normaliza de tal forma que la suma de las alturas es 100
#     * *density*: normaliza de tal forma que el área total de cada histograma es igual a 1
#
# * Parámetro *multiple* tiene las siguientes opciones:
#     * *layer*: sobrepone las graficas con transparencia
#     * *dodge*: pone una barra al lado de la otra cuando hay un hue
#     * *stack*: pone una barra sobre la otra mostrando el total de un mismo bin
#     * *fill*: Pone el total en probabilidad por bin, similar a stack, pero grafica la proporción de cada categoria de hue

# %%
# grafico de histograma
sns.histplot(
    data=propinas,
    x='tip'
)

# mostrar grafica
plt.show()

# %%
# grafico de histograma
sns.histplot(
    data=propinas, #conjunto de datos
    x='tip', # valores a graficar
    bins='stone', # numero de agrupaciones se puede poner un numero o un metodo: 'auto', 'fd', 'doane', 'scott', 'stone', 'rice', 'sturges', or 'sqrt'
)

# mostrar grafica
plt.show()

# %%
# grafico de histograma
sns.histplot(
    data=propinas, #conjunto de datos
    x='tip', # valores a graficar
    bins='auto', # numero de agrupaciones se puede poner un numero o un metodo: 'auto', 'fd', 'doane', 'scott', 'stone', 'rice', 'sturges', or 'sqrt'
    cumulative=True, # para generar un grafico de frecuencias acumuladas
    hue='sex' # campo de agrupamiento
)

# mostrar grafica
plt.show()

# %%
# grafico de histograma
sns.histplot(
    data=propinas, #conjunto de datos
    x='tip', # valores a graficar
    bins='auto', # numero de agrupaciones se puede poner un numero o un metodo: 'auto', 'fd', 'doane', 'scott', 'stone', 'rice', 'sturges', or 'sqrt'
    hue='sex', # campo de agrupamiento
    stat='percent' # opciones: count, frequency, probability o proportion, percent, density
)

# mostrar grafica
plt.show()

# %%
# grafico de histograma
sns.histplot(
    data=propinas, #conjunto de datos
    x='tip', # valores a graficar
    bins='auto', # numero de agrupaciones se puede poner un numero o un metodo: 'auto', 'fd', 'doane', 'scott', 'stone', 'rice', 'sturges', or 'sqrt'
    hue='sex', # campo de agrupamiento
    stat='percent', # opciones: count, frequency, probability o proportion, percent, density
    multiple='dodge' # opciones: layer, dodge, stack, fill
)

# mostrar grafica
plt.show()

# %%
# grafico de histograma
sns.histplot(
    data=propinas, #conjunto de datos
    x='tip', # valores a graficar
    bins='auto', # numero de agrupaciones se puede poner un numero o un metodo: 'auto', 'fd', 'doane', 'scott', 'stone', 'rice', 'sturges', or 'sqrt'
    hue='sex', # campo de agrupamiento
    stat='count', # opciones: count, frequency, probability o proportion, percent, density
    multiple='fill' # opciones: layer, dodge, stack, fill
)

# mostrar grafica
plt.show()

# %% [markdown]
# #### Gráficos *kde* o de densidad

# %%
# grafica de densidad
sns.kdeplot(
    data=propinas, # conjunto de datos
    x = 'tip', # datos para graficar, nombre de columna del conjunto de datos
    hue='sex' # campo de agrupamiento, nombre de columna del conjunto de datos
)

# mostrar grafica
plt.show()

# %%
# grafica de densidad acumulado
sns.kdeplot(
    data=propinas, # conjunto de datos
    x = 'tip', # datos para graficar, nombre de columna del conjunto de datos
    hue='sex', # campo de agrupamiento, nombre de columna del conjunto de datos
    cumulative=True, # grafico de densidad de probabilidad acumularo
)

# mostrar grafica
plt.show()

# %%
# grafica de densidad acumulado
sns.kdeplot(
    data=propinas, # conjunto de datos
    x = 'tip', # datos para graficar, nombre de columna del conjunto de datos
    hue='sex', # campo de agrupamiento, nombre de columna del conjunto de datos
    fill=True # rellena la grafica de area bajo la curva
)

# mostrar grafica
plt.show()

# %%
# grafica de densidad acumulado
sns.kdeplot(
    data=propinas, # conjunto de datos
    x = 'tip', # datos para graficar, nombre de columna del conjunto de datos
    hue='sex', # campo de agrupamiento, nombre de columna del conjunto de datos
    fill=True, # rellena la grafica de area bajo la curva
    bw_adjust=1 # ajusta la grafica
)

# mostrar grafica
plt.show()

# %% [markdown]
# #### Gráfica *ecdf* o de proporciones acumuladas

# %%
# grafica de proporciones acumuladas, se muestra de forma escalonada
sns.ecdfplot(
    data=propinas,  # conjunto de datos
    x='tip', # valores a graficar
    hue='sex' # campo de agrupamiento
)

# muestra la grafica
plt.show()

# %%
# grafica de proporciones acumuladas, se muestra de forma escalonada
sns.ecdfplot(
    data=propinas,  # conjunto de datos
    x='tip', # valores a graficar, nombre de columna del conjunto de datos
    hue='sex', # campo de agrupamiento, nombre de columna del conjunto de datos
    stat='count'
)

# muestra la grafica
plt.show()

# %% [markdown]
# #### Una función que agrupa los tipos de gráficos de distribución es *displot*
# Se le debe dar el parámetro *kind* y definir si es histograma: *'hist'*, de densidad: *'kde'*,  etc.
# Las demás opciones de *stat*, *bins*, *multiple* funcionan como se muestra en la sección [Histogramas](#Histogramas)
#
# * El parámetro *kind* tiene las siguientes opciones:
#     * *hist*: Es una gráfica de tipo histograma, es la que tiene por defecto
#     * *kde*: Gráfica de densidad
#     * *ecdf*: Gráfica de acumulación solo para análiss univariado, un solo dato a la vez

# %%
# graficas usando displot
sns.displot(
    data=propinas, # conjunto de datos
    x='tip', # valores a graficar, nombre de columna del conjunto de datos
    hue='sex' # campo de agrupamiento, nombre de columna de conjunto de datos
)

# mostrar grafica
plt.show()

# %%
# graficas usando displot
sns.displot(
    data=propinas, # conjunto de datos
    x='tip', # valores a graficar, nombre de columna del conjunto de datos
    hue='sex', # campo de agrupamiento, nombre de columna de conjunto de datos
    kind='kde', # aca se define el tipo de grafica: 'hist', 'kde' o 'ecdf'
)

# mostrar grafica
plt.show()

# %% [markdown]
# ### Gráfica de variables categóricas con Seaborn

# %%
propinas.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### Count plot

# %%
# grafica countplot, cuenta cuantos registros de la variable categorica hay
sns.countplot(
    data=propinas, # conjunto de datos
    x='day', # variable a graficar, debe ser categorica
    hue='sex' # campo de agrupamiento, nombre de columna de conjunto de datos
)

# mostrar grafica
plt.show()

# %%
# grafica countplot, cuenta cuantos registros de la variable categorica hay
sns.countplot(
    data=propinas, # conjunto de datos
    y='day', # variable a graficar, debe ser categorica
    hue='sex' # campo de agrupamiento, nombre de columna de conjunto de datos
)

# mostrar grafica
plt.show()

# %% [markdown]
# #### Strip plot

# %%
# grafica strip
sns.stripplot(
    data=propinas, # conjunto de datos
    x='day', # variable categorica
    y='total_bill', # variable numerica que quiero conocer respecto a las categorias
    hue='sex', # campo de agrupamiento, nombre de columna de conjunto de datos
    dodge=True # para poner uno al lado del otro con del campo usado para agrupar
)

# mostrar grafica
plt.show()

# %% [markdown]
# #### Swarm plot

# %%
# grafica swarm
sns.swarmplot(
    data=propinas, # conjunto de datos
    x='day', # variable categorica
    y='total_bill', # variable numerica que quiero conocer respecto a las categorias
    hue='sex', # campo de agrupamiento, nombre de columna de conjunto de datos
    dodge=True # para poner uno al lado del otro con del campo usado para agrupar
)

# mostrar grafica
plt.show()

# %%
# grafica boxplot
sns.boxplot(
    data=propinas, # conjunto de datos
    x='day', # variable categorica
    y='total_bill', # variable numerica que quiero conocer respecto a las categorias
    hue='sex', # campo de agrupamiento, nombre de columna de conjunto de datos
    dodge=True # para poner uno al lado del otro con del campo usado para agrupar
)

# mostrar grafica
plt.show()

# %%
# combinacion de graficas boxplot y swarmplot
# grafica boxplot
sns.boxplot(
    data=propinas, # conjunto de datos
    x='day', # variable categorica
    y='total_bill', # variable numerica que quiero conocer respecto a las categorias
    hue='sex', # campo de agrupamiento, nombre de columna de conjunto de datos
    dodge=True # para poner uno al lado del otro con del campo usado para agrupar
)
# grafica swarmplot
sns.swarmplot(
    data=propinas, # conjunto de datos
    x='day', # variable categorica
    y='total_bill', # variable numerica que quiero conocer respecto a las categorias
    hue='sex', # campo de agrupamiento, nombre de columna de conjunto de datos
    dodge=True, # para poner uno al lado del otro con del campo usado para agrupar
    palette='dark:black' # cambia el color de los puntos
)

# mostrar grafica
plt.show()

# %%
# grafica violin plot
sns.violinplot(
    data=propinas, # conjunto de datos
    x='day', # variable categorica
    y='total_bill', # variable numerica que quiero conocer respecto a las categorias
    hue='sex', # campo de agrupamiento, nombre de columna de conjunto de datos
    split=True # separa hombres y mujeres y hace un grafico para cada distribucion
)

# mostrar grafica
plt.show()

# %% [markdown]
# #### Catplot, agrupa gráficos de tipo categórico

# %%
# grafica catplot, por defecto es stripplot
sns.catplot(
    data=propinas, # conjunto de datos
    x='day', # variable categorica
    y='total_bill', # variable numerica que quiero conocer respecto a las categorias
    hue='sex' # campo de agrupamiento, nombre de columna de conjunto de datos
)

# muestra la grafica
plt.show()

# %%
# grafica catplot
sns.catplot(
    data=propinas, # conjunto de datos
    x='day', # variable categorica
    y='total_bill', # variable numerica que quiero conocer respecto a las categorias
    hue='sex', # campo de agrupamiento, nombre de columna de conjunto de datos
    kind='box' # recibe los siguientes: strip, swarm, box, violin, boxen, point, bar, count 
)

# muestra la grafica
plt.show()

# %%
# grafica catplot
sns.catplot(
    data=propinas, # conjunto de datos
    x='day', # variable categorica
    y='total_bill', # variable numerica que quiero conocer respecto a las categorias
    hue='sex', # campo de agrupamiento, nombre de columna de conjunto de datos
    kind='box', # recibe los siguientes: strip, swarm, box, violin, boxen, point, bar, count 
    col='time' # separa en axes diferentes segun otra variable categorica
)

# muestra la grafica
plt.show()

# %% [markdown]
# ### Gráficos de tipos relación con Seaborn

# %%
propinas.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### Scatter plot

# %%
# grafico de dispersion
sns.scatterplot(
    data=propinas, # conjunto de datos
    x='total_bill', # dato numerico para eje x, se pone nombre de columna de conjunto de datos
    y='tip' # dato numerico para eje y, se pone el nombre de la columna del conjunto de datos
)

plt.show()

# %%
# grafico de dispersion
sns.scatterplot(
    data=propinas, # conjunto de datos
    x='total_bill', # dato numerico para eje x, se pone nombre de columna de conjunto de datos
    y='tip', # dato numerico para eje y, se pone el nombre de la columna del conjunto de datos
    hue='day' # agrupar por dia
)

plt.show()

# %%
# grafico de dispersion
sns.scatterplot(
    data=propinas, # conjunto de datos
    x='total_bill', # dato numerico para eje x, se pone nombre de columna de conjunto de datos
    y='tip', # dato numerico para eje y, se pone el nombre de la columna del conjunto de datos
    hue='day', # agrupar por dia
    style='time' #variable categorica para dar simbologia a los puntos
)

plt.show()

# %%
# grafico de dispersion
sns.scatterplot(
    data=propinas, # conjunto de datos
    x='total_bill', # dato numerico para eje x, se pone nombre de columna de conjunto de datos
    y='tip', # dato numerico para eje y, se pone el nombre de la columna del conjunto de datos
    hue='day', # agrupar por dia
    style='time', #variable categorica para dar simbologia a los puntos
    size='size' # tamano de marcadores, se asigno con una columna numerica del conjunto de datos
)

plt.legend(loc='center', # para centrar leyenda
           bbox_to_anchor=(1.10, 0.5)) # para mover la caja de la leyenda (xpos, ypos)

plt.show()

# %%
# grafico de dispersion
plt.figure(figsize=(8, 8)) # para cambiar el tamano del lienzo
sns.scatterplot(
    data=propinas, # conjunto de datos
    x='total_bill', # dato numerico para eje x, se pone nombre de columna de conjunto de datos
    y='tip', # dato numerico para eje y, se pone el nombre de la columna del conjunto de datos
    hue='day', # agrupar por dia
    style='time', #variable categorica para dar simbologia a los puntos
    size='size' # tamano de marcadores, se asigno con una columna numerica del conjunto de datos
)

plt.legend(loc='center', # para centrar leyenda
           bbox_to_anchor=(1.10, 0.5)) # para mover la caja de la leyenda (xpos, ypos)

plt.show()

# %% [markdown]
# #### Relplot agrupa los tipos de gráficos de relación

# %%
# grafico relplot, por defecto hace un grafico de dispersion
sns.relplot(
    data=propinas, # conjunto de datos
    x='total_bill', # variable numerica para x, se pone nombre de columna del conjunto de datos
    y='tip' # variable numerica para y, se pone nombre de columna del conjunto de datos
)

# muestra grafica
plt.show()

# %%
# grafico relplot, por defecto hace un grafico de dispersion
sns.relplot(
    data=propinas, # conjunto de datos
    x='total_bill', # variable numerica para x, se pone nombre de columna del conjunto de datos
    y='tip', # variable numerica para y, se pone nombre de columna del conjunto de datos
    kind='line' # se elige el tipo de grafico, acepta las siguientes opciones: scatter y  line
)

# muestra grafica
plt.show()

# %% [markdown]
# ### Joinplot y Pairplot

# %%
propinas.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# grafica jointplot
sns.jointplot(
    data=propinas, # conjunto de datos 
    x='total_bill', # variable numerica para x, se pone el nombre de la columna del conjunto de datos
    y='tip' # variable numerica para y, se pone el nombre de la columna del conjunto de datos
)

# mostrar grafica
plt.show()

# %%
# jointplot muestra dos tipos de graficas al tiempo
sns.jointplot(
    data=propinas, # conjunto de datos 
    x='total_bill', # variable numerica para x, se pone el nombre de la columna del conjunto de datos
    y='tip', # variable numerica para y, se pone el nombre de la columna del conjunto de datos
    hue='sex' # categoria para separar datos
)

# mostrar grafica
plt.show()

# %%
# jointplot muestra dos tipos de graficas al tiempo
sns.jointplot(
    data=propinas, # conjunto de datos 
    x='total_bill', # variable numerica para x, se pone el nombre de la columna del conjunto de datos
    y='tip', # variable numerica para y, se pone el nombre de la columna del conjunto de datos
    hue='sex', # categoria para separar datos
    kind='hist' # se elige el tipo de grafica recibe las siguientes opciones: scatter, kde, hist, hex, reg, resid
)

# mostrar grafica
plt.show()

# %%
# jointplot muestra dos tipos de graficas al tiempo
sns.jointplot(
    data=propinas, # conjunto de datos 
    x='total_bill', # variable numerica para x, se pone el nombre de la columna del conjunto de datos
    y='tip', # variable numerica para y, se pone el nombre de la columna del conjunto de datos
    hue='sex', # categoria para separar datos
    kind='kde' # se elige el tipo de grafica recibe las siguientes opciones: scatter, kde, hist, hex, reg, resid
)

# mostrar grafica
plt.show()

# %%
# jointplot muestra dos tipos de graficas al tiempo
sns.jointplot(
    data=propinas, # conjunto de datos 
    x='total_bill', # variable numerica para x, se pone el nombre de la columna del conjunto de datos
    y='tip', # variable numerica para y, se pone el nombre de la columna del conjunto de datos
    hue='sex', # categoria para separar datos
    kind='hist', # se elige el tipo de grafica recibe las siguientes opciones: scatter, kde, hist, hex, reg, resid
    marginal_ticks=True, # para agregarle ejes a las graficas de arriba y la derecha
    marginal_kws=dict(bins=25, # cambia numero de bins de las graficas de los lados
                      fill=True, # deja relleno de barras de histograma, si se pone False deja solo los bordes
                      multiple='dodge' # pone una barra al lado de la otra en los histrogramas
                      )
)

# mostrar grafica
plt.show()

# %% [markdown]
# #### Pairplot

# %%
# grafico pairplot, toma los datos numericos
sns.pairplot(
    data=propinas, # conjunto de datos
)

# mostrar graficas
plt.show()

# %%
# grafico pairplot, toma los datos numericos
sns.pairplot(
    data=propinas, # conjunto de datos
    hue='sex' # para agrupar datos por variable categorica
    
)

# mostrar graficas
plt.show()

# %%
# grafico pairplot, toma los datos numericos
sns.pairplot(
    data=propinas, # conjunto de datos
    hue='sex', # para agrupar datos por variable categorica
    kind='reg' # elijo los tipos de graficos, admite: scatter, kde, hist y reg
    
)

# mostrar graficas
plt.show()

# %% [markdown]
# ### Gráfico heatmap, usado para ver correlaciones

# %%
propinas.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# se obtiene matriz de correlaciones
propinas.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# se pone la matriz de correlacion como grafica
sns.heatmap(
    propinas.corr(numeric_only=True) # datos a graficas
)
plt.show()

# %%
# se pone la matriz de correlacion como grafica
sns.heatmap(
    propinas.corr(numeric_only=True), # datos a graficar
    annot=True # muestra los valores de correlacion
)
plt.show()

# %%
# se pone la matriz de correlacion como grafica
sns.heatmap(
    propinas.corr(numeric_only=True), # datos a graficar
    annot=True, # muestra los valores de correlacion
    cmap='coolwarm' # cambia color cuadros de la grafica
)
plt.show()

# %%
# se pone la matriz de correlacion como grafica
sns.heatmap(
    propinas.corr(numeric_only=True), # datos a graficar
    annot=True, # muestra los valores de correlacion
    cmap='coolwarm', # cambia color cuadros de la grafica
    linewidths=5 # ancho de linea, sirve para dar la sensacion de separacion de cuadro
)
plt.show()

# %%
# se pone la matriz de correlacion como grafica
sns.heatmap(
    propinas.corr(numeric_only=True), # datos a graficar
    annot=True, # muestra los valores de correlacion
    cmap='coolwarm', # cambia color cuadros de la grafica
    linewidths=5, # ancho de linea, sirve para dar la sensacion de separacion de cuadro
    linecolor='black' # cambia color de linea
)
plt.show()

# %%
# se pone la matriz de correlacion como grafica
sns.heatmap(
    propinas.corr(numeric_only=True), # datos a graficar
    annot=True, # muestra los valores de correlacion
    cmap='coolwarm', # cambia color cuadros de la grafica
    linewidths=5, # ancho de linea, sirve para dar la sensacion de separacion de cuadro
    linecolor='white', # cambia color de linea
    vmin=-1, # define valor minimo de escala, se uso -1 porque la correlacion va entre -1 y 1
    vmax=1 # define valor maximo de escala
)
plt.show()

# %%
# se pone la matriz de correlacion como grafica
sns.heatmap(
    propinas.corr(numeric_only=True), # datos a graficar
    annot=True, # muestra los valores de correlacion
    cmap='coolwarm', # cambia color cuadros de la grafica
    linewidths=5, # ancho de linea, sirve para dar la sensacion de separacion de cuadro
    linecolor='white', # cambia color de linea
    vmin=-1, # define valor minimo de escala
    vmax=1, # define valor maximo de escala
    cbar=True # muestra la barra lateral con la escala, se puede ocultar poniendo en False
)
plt.show()
